# %% [markdown]
# ## **Housing Price Prediction Using Linear Regression**

# %%
#imports
import numpy as np
import matplotlib.pyplot as plt

# %%
# x_train is the input variable (size in 1000 square feet)
x_train = np.array([1.0, 2.0, 3.0, 4.0])

# y_train is the target (price in 1000s of dollars)
y_train = np.array([300.0, 500.0, 700.00, 900.00])

print(f"input:   x_train = {x_train}")
print(f"output:  y_train = {y_train}")
# Out:
# input:   x_train = [1. 2. 3. 4.]
# output:  y_train = [300. 500. 700. 900.]

# %%
# .shape returns a tuple that specify the # of elements in each dimension
print(f"x_train.shape: {x_train.shape}")

# m is the number of training examples
m = x_train.shape[0]
# or 
m = len(x_train)

print(f"Number of training examples is: {m}")
# Out:
# x_train.shape: (4,)
# Number of training examples is: 4

# %%
# i = 0 

# x_i = x_train[i]
# y_i = y_train[i]
# print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")

# for loop to print all training examples 
for i in range(len(x_train)):
   x_i = x_train[i]
   y_i = y_train[i]
   print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)
# (x^(1), y^(1)) = (2.0, 500.0)
# (x^(2), y^(2)) = (3.0, 700.0)
# (x^(3), y^(3)) = (4.0, 900.0)

# %% [markdown]
# ## Plot the data points

# %%
# default version
#plt.scatter(x_train, y_train)           

# print data points as "red" "crosses"
plt.scatter(x_train, y_train, marker='x', c='r')

# Set the title
plt.title("Housing Prices")

# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')

# Set the x-axis label
plt.xlabel('Size (1000 sqft)')

plt.show()

# %% [markdown]
# ## Model function
#
# the model function for linear regression (which is a function that maps from `x` to `y`) is represented as :
#
# $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
#
# The formula is how you can represent straight lines - different values of $w$ and $b$ give you different straight lines on the plot.

# %%
w = 200
b = 100
print(f"weight: {w}")
print(f"bias: {b}")
# Out:
# weight: 200
# bias: 100

# %% [markdown]
# ## function for computing the value of $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
#  The argument description `(ndarray (m,))` describes a Numpy n-dimensional array of shape (m,). `(scalar)` describes an argument without dimensions, just a magnitude.
# `np.zero(n)` will return a one-dimensional numpy array with $n$ entries

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      f_wb (ndarray (m,)): model prediction
    """
    m = x.shape[0]

    # initialize f_wb to an array of size m, filled with zero's
    f_wb = np.zeros(m)
    
    for i in range(m):
        f_wb[i] = w * x[i] + b
        
    return f_wb

# %% [markdown]
# ## plotting the line

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")

# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')

# Set the x-axis label
plt.xlabel('Size (1000 sqft)')

plt.legend()

plt.show()

# %% [markdown]
# ## prediction

# %%
w = 200                         
b = 100    

#new x value
x_i = 1.2  

#prediction
cost_1200sqft = w * x_i + b    

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars
